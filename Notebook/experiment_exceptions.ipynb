# %%
import sys
import traceback

# %%
class DocumentPortalException(Exception):
    def __init__(self, error_message, error_details:sys):
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.line_no=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"""
        Error occurred in script: {self.file_name} at line number: {self.line_no} 
        with message: {self.error_message}
        \nTraceback Details:\n{self.traceback_str}"""
        #return "Document Portal Exception occurred"

    if __name__ == "__main__":
        try:
            a = 1 / 0 
        except Exception as e:
            app_exc = DocumentPortalException(e, sys)
            raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 24, in DocumentPortalException()
#      22             app_exc = DocumentPortalException(e, sys)
#      23         # Wraps the original error and sys module into our custom exception for enriched error info
# ---> 24             raise app_exc
#      25         # Re-raises the custom exception with detailed file, line, and traceback information
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class DocumentPortalException(Exception):
#       2     def __init__(self, error_message, error_details:sys):
#       3         _,_,exc_tb=error_details.exc_info()
#       4         self.file_name=exc_tb.tb_frame.f_code.co_filename
#
# Cell In[3], line 24, in DocumentPortalException()
#      20         except Exception as e:
#      21         # e: the caught ZeroDivisionError exception instance
#      22             app_exc = DocumentPortalException(e, sys)
#      23         # Wraps the original error and sys module into our custom exception for enriched error info
# ---> 24             raise app_exc
#      25         # Re-raises the custom exception with detailed file, line, and traceback information
#
# DocumentPortalException:
#         Error occurred in script: /var/folders/v3/gzqtl7td46nbcbn7qy84rqpw0000gp/T/ipykernel_88725/2832062864.py at line number: 19
#         with message: division by zero
#
# Traceback Details:
# Traceback (most recent call last):
#   File "/var/folders/v3/gzqtl7td46nbcbn7qy84rqpw0000gp/T/ipykernel_88725/2832062864.py", line 19, in DocumentPortalException
#     a = 1 / 0  # Intentionally causes a ZeroDivisionError to test the custom exception
#         ~~^~~
# ZeroDivisionError: division by zero

# %%
# 1. Log this information(file, cloud configuration, command prompt) (It will keep the error details and not stop the execution of code)
# 2. Raise the exception(it will stop the execution of the code)

# %%
## __file__ in .py file automatically gets the name of the file where it is written. But in Jupyter Notebooks, we have to manually specify it.

# %%
import os, sys
sys.path.append(os.path.abspath(".."))

from logger.custom_logger import CustomLogger
logger=CustomLogger().get_logger("exception_experiment") #Specify the file name manually here in ipynb. 
#In .py file the name is captured automatically using __file__

# %%
import sys
import traceback

class DocumentPortalException(Exception):
    """Custom exception for Document Portal"""
    def __init__(self,error_message,error_details:sys):
        print(error_details.exc_info())
        _,_,exc_tb=error_details.exc_info()
        self.file_name=exc_tb.tb_frame.f_code.co_filename
        self.lineno=exc_tb.tb_lineno
        self.error_message=str(error_message)
        self.traceback_str=''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"""
        Error occurred in [{self.file_name}] at line number: {self.lineno} 
        with message: {self.error_message}
        \nTraceback Details:\n{self.traceback_str}"""
        #return "Document Portal Exception occurred"
    
if __name__ == "__main__":
    try:
        a = 1 / 0
        print(a)
    except Exception as e:
        app_exc=DocumentPortalException(e,sys)
        logger.error(app_exc)
        raise app_exc
# Out:
# (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x10a2b8080>)
# 2026-04-08 13:18:34 [error    ]
#         Error occurred in [/var/folders/v3/gzqtl7td46nbcbn7qy84rqpw0000gp/T/ipykernel_88725/27542482.py] at line number: 23
#         with message: division by zero
#
# Traceback Details:
# Traceback (most recent call last):
#   File "/var/folders/v3/gzqtl7td46nbcbn7qy84rqpw0000gp/T/ipykernel_88725/27542482.py", line 23, in <module>
#     a = 1 / 0
#         ~~^~~
# ZeroDivisionError: division by zero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 28
#      26         app_exc=DocumentPortalException(e,sys)
#      27         logger.error(app_exc)
# ---> 28         raise app_exc
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[5], line 28
#      24         print(a)
#      25     except Exception as e:
#      26         app_exc=DocumentPortalException(e,sys)
#      27         logger.error(app_exc)
# ---> 28         raise app_exc
#
# DocumentPortalException:
#         Error occurred in [/var/folders/v3/gzqtl7td46nbcbn7qy84rqpw0000gp/T/ipykernel_88725/27542482.py] at line number: 23
#         with message: division by zero
#
# Traceback Details:
# Traceback (most recent call last):
#   File "/var/folders/v3/gzqtl7td46nbcbn7qy84rqpw0000gp/T/ipykernel_88725/27542482.py", line 23, in <module>
#     a = 1 / 0
#         ~~^~~
# ZeroDivisionError: division by zero
