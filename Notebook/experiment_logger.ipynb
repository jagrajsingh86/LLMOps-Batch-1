# %%
print("all is well")
# Out:
# all is well

# %%
import logging
import os
from datetime import datetime

# %%
os.getcwd()
# Out:
# '/Users/2099070/Documents/Cognizant/LLMOps Batch 1/Notebook'

# %%
#Create a Log Directory
logs_dir = os.path.join(os.getcwd(), "logs")
os.makedirs(logs_dir, exist_ok=True)

# %%
logs_dir
# Out:
# '/Users/2099070/Documents/Cognizant/LLMOps Batch 1/Notebook/logs'

# %%
LOG_FILE = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}.log"

LOG_FILE
# Out:
# '04_07_2026_14_20_36.log'

# %%
#today
# with today's date log file will be creted

#tomorrow
# with tomorrow's date log file will be created

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)

LOG_FILE_PATH
# Out:
# '/Users/2099070/Documents/Cognizant/LLMOps Batch 1/Notebook/logs/04_07_2026_14_20_36.log'

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
)

# %%
logger=logging.getLogger("DocumentPorta")

# %%
logger.info("This is an info message")

# %%
## python concept or python basics should be clear

# %%
import structlog
logger = structlog.get_logger()

# %%
logger.info("User uploaded a file", file_name="document.pdf", user_id=12345)
# Out:
# 2026-04-07 14:21:56 [info     ] User uploaded a file           file_name=document.pdf user_id=12345
